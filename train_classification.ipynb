# %%
# !ls
# Out:
# LICENSE.md	  data_train		     requirements.txt
# README.md	  data_train_mask	     split.py
# Readme.md	  data_utils		     tlt-converter
# badimgs.txt	  detectnet_v2		     tlt_peoplenet_pruned_v2.0
# check_dataset.py  ds_configs		     tlt_specs
# cmd		  face-mask-detection.ipynb  train_classification.ipynb
# data		  images
# data2kitti.py	  ouput

# %%
# !tlt-train classification -e ./mask_classify/config/mask_classify_train.txt -r /workspace/mask_classify/output -k tlt_encode
# Out:
# Using TensorFlow backend.
# 2020-10-13 02:36:37.499403: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcudart.so.10.0
# 2020-10-13 02:36:39.528599: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcuda.so.1
# 2020-10-13 02:36:39.541757: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:983] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2020-10-13 02:36:39.542080: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1618] Found device 0 with properties:
# name: GeForce RTX 2080 Ti major: 7 minor: 5 memoryClockRate(GHz): 1.545
# pciBusID: 0000:01:00.0
# 2020-10-13 02:36:39.542098: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcudart.so.10.0
# ...

# %%
# !tlt-evaluate classification -e ./mask_classify/config/mask_classify_train.txt -k tlt_encode
# Out:
# Using TensorFlow backend.
# 2020-10-13 02:45:39.097499: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcudart.so.10.0
# 2020-10-13 02:45:41.090544: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcuda.so.1
# 2020-10-13 02:45:41.119185: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:983] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2020-10-13 02:45:41.119555: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1618] Found device 0 with properties:
# name: GeForce RTX 2080 Ti major: 7 minor: 5 memoryClockRate(GHz): 1.545
# pciBusID: 0000:01:00.0
# 2020-10-13 02:45:41.119575: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcudart.so.10.0
# ...

# %%
# !tlt-int8-tensorfile classification -e ./mask_classify/config/mask_classify_train.txt -m 4 -o ./mask_classify/final_output/calibration.tensor
# Out:
# Using TensorFlow backend.
# 2020-10-13 02:55:58.734308: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcudart.so.10.0
# 2020-10-13 02:56:00,757 [INFO] iva.makenet.scripts.dump_samples: Loading experiment spec at ./mask_classify/config/mask_classify_train.txt
# 2020-10-13 02:56:00,759 [INFO] iva.makenet.scripts.dump_samples: Setting up input generator.
# Found 3006 images belonging to 2 classes.
# Writing calibration tensorfile: 100%|█████████████| 4/4 [00:00<00:00,  4.85it/s]
# 2020-10-13 02:56:01,695 [INFO] iva.makenet.scripts.dump_samples: Calibration tensorfile written.

# %%
# !tlt-export classification -m ./mask_classify/output/weights/resnet_040.tlt -k tlt_encode -o ./mask_classify/final_output/mask_calssify.etlt
# Out:
# Using TensorFlow backend.
# 2020-10-13 03:05:29.268350: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcudart.so.10.0
# 2020-10-13 03:05:31.546390: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcuda.so.1
# 2020-10-13 03:05:31.546527: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:983] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2020-10-13 03:05:31.546842: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1618] Found device 0 with properties:
# name: GeForce RTX 2080 Ti major: 7 minor: 5 memoryClockRate(GHz): 1.545
# pciBusID: 0000:01:00.0
# 2020-10-13 03:05:31.546861: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcudart.so.10.0
# ...

# %%
# !tlt-export classification -m ./mask_classify/output/weights/resnet_040.tlt -k tlt_encode -o ./mask_classify/final_output/mask_calssify_fp16.etlt --data_type fp16
# Out:
# Using TensorFlow backend.
# 2020-10-13 03:10:36.690609: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcudart.so.10.0
# 2020-10-13 03:10:38.886881: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcuda.so.1
# 2020-10-13 03:10:38.887055: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:983] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2020-10-13 03:10:38.887450: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1618] Found device 0 with properties:
# name: GeForce RTX 2080 Ti major: 7 minor: 5 memoryClockRate(GHz): 1.545
# pciBusID: 0000:01:00.0
# 2020-10-13 03:10:38.887470: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcudart.so.10.0
# ...

# %%
# !tlt-infer classification -m ./mask_classify/output/weights/resnet_040.tlt -d data_train_mask/test/mask -b 1 -k tlt_encode -cm mask_classify/output/classmap.json
# Out:
# Using TensorFlow backend.
# 2020-10-13 06:02:51.227379: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcudart.so.10.0
# 2020-10-13 06:02:54.212154: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcuda.so.1
# 2020-10-13 06:02:54.242715: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:983] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2020-10-13 06:02:54.243066: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1618] Found device 0 with properties:
# name: GeForce RTX 2080 Ti major: 7 minor: 5 memoryClockRate(GHz): 1.545
# pciBusID: 0000:01:00.0
# 2020-10-13 06:02:54.243094: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcudart.so.10.0
# ...

# %%
# !tlt-export classification \
            -m ./mask_classify/output/weights/resnet_040.tlt \
            -o ./mask_classify/final_output/mask_classify_int8.etlt \
            -k tlt_encode  \
            --cal_data_file ./mask_classify/mask_final_output/calibration.tensor \
            --data_type int8 \
            --batches 4 \
            --batch_size 4 \
            --max_batch_size 4\
            --engine_file ./mask_classify/mask_final_output/mask_classify_int8.engine \
            --cal_cache_file ./mask_classify/mask_final_output/calibration.bin  \
            --verbose
# Out:
# Using TensorFlow backend.
# 2020-10-13 06:16:05.577480: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcudart.so.10.0
# 2020-10-13 06:16:07.666233: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcuda.so.1
# 2020-10-13 06:16:07.666367: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:983] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2020-10-13 06:16:07.666673: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1618] Found device 0 with properties:
# name: GeForce RTX 2080 Ti major: 7 minor: 5 memoryClockRate(GHz): 1.545
# pciBusID: 0000:01:00.0
# 2020-10-13 06:16:07.666691: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcudart.so.10.0
# ...
